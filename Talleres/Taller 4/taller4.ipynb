# %% [markdown]
# # **Analítica Computacional para la toma de Decisiones Avanzada 202610**
# ### *Departamento de Ingeniería Industrial*
# ### TALLER 4
#
# Daniel Benavides, Juanita Cortés
#
# <d.benavidess@uniandes.edu.co, jv.cortesv1@uniandes.edu.co>

# %%
import pandas as pd
import numpy as np

# %%
df_daily = pd.read_csv('WHO-COVID-19-global-daily-data.csv')
df_daily.head()
# Out:
#   Date_reported Country_code         Country WHO_region  New_cases  \
# 0    2020-01-04           AF     Afghanistan        EMR        NaN
# 1    2020-01-04           DZ         Algeria        AFR        NaN
# 2    2020-01-04           AL         Albania        EUR        NaN
# 3    2020-01-04           AI        Anguilla        AMR        NaN
# 4    2020-01-04           AS  American Samoa        WPR        0.0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         0.0                  0

# %%
df_country_codes = pd.read_csv('countries_codes_and_coordinates.csv')
df_country_codes.head()
# Out:
#           Country Alpha-2 code Alpha-3 code Numeric code Latitude (average)  \
# 0     Afghanistan         "AF"        "AFG"          "4"               "33"
# 1   Åland Islands         "AX"        "ALA"        "248"        "60.116667"
# 2         Albania         "AL"        "ALB"          "8"               "41"
# 3         Algeria         "DZ"        "DZA"         "12"               "28"
# 4  American Samoa         "AS"        "ASM"         "16"         "-14.3333"
#
#   Longitude (average)
# 0                "65"
# 1              "19.9"
# 2                "20"
# 3                 "3"
# 4              "-170"
